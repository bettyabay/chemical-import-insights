# %%
# Import necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import os, sys
# Add the 'scripts' directory to the Python path for module imports
sys.path.append(os.path.abspath(os.path.join('..', 'scripts')))

# Set max rows and columns to display
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 200)

# Configure logging
# Assuming this class is defined in scripts/
from data_preprocessing import DataPreprocessor

# %%
processor = DataPreprocessor

# %%
Chm_Import_data = processor.get_data("../data/raw/Import Data Mining.xlsx")
# Out:
# 2025-03-08 00:32:17,108 - INFO - Successfully imported XLSX file: ../data/raw/Import Data Mining.xlsx

# %%
Chm_Import_data.head()
# Out:
#   IMPEX BANK PERMIT NUMBER Reg. Date (Day/Mon/Year)             TIN  \
# 0    IM                NaN               15/07/2022  0039580266ET03
# 1    IM  ABAIBD01000432023               14/06/2023  0039580266ET03
# 2    IM  OIBIBD01006972023               09/09/2023  0039580266ET03
# 3    IM  ABAIBD01000502023               22/09/2023  0041705943ET02
# 4    IM  UNBUBH01001882022               03/07/2022  0046675365AARI
#
#                       Trader  \
# 0  A E CHEMICALS TRADING PLC
# 1  A E CHEMICALS TRADING PLC
# 2  A E CHEMICALS TRADING PLC
# 3            A F TRADING PLC
# 4    ABDULAZIZ KEDIR HUSSEIN
#
#                                       Trader Address  Item     HS Code  \
# 0  X (ADDIS ABABA) (ZN-YEKA WR-NO WOREDA-143) (KB...   3.0  39053000.0
# 1  X (ADDIS ABABA) (ZN-YEKA WR-NO WOREDA-143) (KB...   1.0  39051200.0
# 2  X (ADDIS ABABA) (ZN-YEKA WR-NO WOREDA-143) (KB...   1.0  39051200.0
# 3  14/670/199525/2006 (ADDIS ABABA) (ZN-ARADA WR-...   1.0  39051200.0
# 4  29337/07 (ADDIS ABABA) (ZN-AKAKI KALITI WR-NO ...   1.0  39059900.0
#
#                                       HS Description  \
# 0  - Poly(vinyl alcohol), whether or not containi...
# 1                           -- In aqueous dispersion
# 2                           -- In aqueous dispersion
# 3                           -- In aqueous dispersion
# 4                                           -- Other
#
#                   Commercial / Brand Name      Country (Origin)  \
# 0   POLYVINYL ALCOHOL GOHSENOL GH 20R ( )                 China
# 1                         HOMOPOLYMER ( )  United Arab Emirates
# 2  HOMOPOLYMER VISICOL 3001 OFF GRADE ( )  United Arab Emirates
# 3                         HOMOPOLYMER ( )  United Arab Emirates
# 4                        PP  25KG/BAG ( )              Thailand
#
#   Country (Consignment) Destination  CIF/FOB Value (ETB)  FOB (FC)  \
# 0  United Arab Emirates    Ethiopia                166.0      2.79
# 1  United Arab Emirates    Ethiopia            3693135.0  62800.00
# 2  United Arab Emirates    Ethiopia            3741930.0  62800.00
# 3  United Arab Emirates    Ethiopia            1874001.0  31400.00
# 4              Djibouti    Ethiopia            3613113.0  60736.50
#
#   CURRENCY CODE  # of packages  MoT Code                  MoT Description  \
# 0           USD            1.0       4.0                    AIR TRANSPORT
# 1           USD          160.0      62.0  MULTIMODAL TRANSPORT (SEA ROAD)
# 2           USD          160.0      62.0  MULTIMODAL TRANSPORT (SEA ROAD)
# 3           USD           80.0      62.0  MULTIMODAL TRANSPORT (SEA ROAD)
# 4           USD         1980.0      61.0    UNIMODAL TRANSPORT (SEA ROAD)
#
#    Suppl. Quantity  Gross Wt. (Kg)  Net Wt. (Kg)  Duty tax tobe paid (ETB)  \
# 0              NaN             2.0           2.0                      8.30
# 1              NaN         41600.0       40000.0                 184656.80
# 2              NaN         41600.0       40000.0                 187096.50
# 3              NaN         20800.0       20000.0                  93700.05
# 4              NaN         52000.0       49500.0                 180655.60
#
#    Duty tax paid (ETB)  Excise tax tobe paid (ETB)  Excise tax paid (ETB)  \
# 0                 8.30                         0.0                    0.0
# 1            184656.80                         0.0                    0.0
# 2            187096.50                         0.0                    0.0
# 3             93700.05                         0.0                    0.0
# 4            180655.60                         0.0                    0.0
#
#    VAT tobe paid (ETB)  VAT paid (ETB)  WH tax tobe paid (ETB)  \
# 0                 26.1            26.1                    4.98
# 1             581668.8        581668.8               110794.10
# 2             589354.1        589354.1               112257.90
# 3             295155.2        295155.2                56220.03
# 4             569065.3        569065.3               108393.40
#
#    WH tax paid (ETB)  Sur tax tobe paid (ETB)  Sur tax paid (ETB)  \
# 0               4.98                      0.0                 0.0
# 1          110794.10                      0.0                 0.0
# 2          112257.90                      0.0                 0.0
# 3           56220.03                      0.0                 0.0
# 4               0.00                      0.0                 0.0
#
#    Social Wel Tax tobe paid (ETB)  Social Wel Tax paid (ETB)  \
# 0                            0.00                       0.00
# 1                       110794.10                  110794.10
# 2                       112257.90                  112257.90
# 3                        56220.03                   56220.03
# 4                            0.00                       0.00
#
#    Total tax tobe paid (ETB)  Total tax paid (ETB)
# 0                      39.38                 39.38
# 1                  987913.80             987913.80
# 2                 1000966.40            1000966.40
# 3                  501295.31             501295.31
# 4                  858114.30             749720.90

# %%
Chm_Import_data.tail()
# Out:
#     IMPEX BANK PERMIT NUMBER Reg. Date (Day/Mon/Year)             TIN  \
# 311    IM                NaN               06/02/2023  0055267582AAFI
# 312    IM  ABAIBD01003802023               28/11/2023  0086235515ET02
# 313    IM                NaN               12/04/2023  0051803592AAFI
# 314   NaN                NaN                      NaN             NaN
# 315   NaN                NaN                      NaN             NaN
#
#                              Trader  \
# 311               ZHIBIN WANG -----
# 312  ZOI  ENGINEERING AND TRADE PLC
# 313                    ZUYING XUE .
# 314                             NaN
# 315                             NaN
#
#                                         Trader Address  Item     HS Code  \
# 311  EIC-IP/25164/10 (ADDIS ABABA) (ZN-NEFAS SILK L...   2.0  39052900.0
# 312  MT/AA/14/706/4611130/2016 (ADDIS ABABA) (ZN-KI...   4.0  39053000.0
# 313  x (OROMIA) (ZN-FINFINE VIC S WR-Gelan Town Adm...   1.0  39052900.0
# 314                                                NaN   NaN         NaN
# 315                                                NaN   NaN         NaN
#
#                                         HS Description  \
# 311                                           -- Other
# 312  - Poly(vinyl alcohol), whether or not containi...
# 313                                           -- Other
# 314                                                NaN
# 315                                                NaN
#
#                 Commercial / Brand Name Country (Origin)  \
# 311  RE-DISPERSIBLE EMULSION POWDER ( )            China
# 312             POLY VINYL ALCHOHOL ( )            Italy
# 313                   PVC  MATERIAL ( )         Viet Nam
# 314                                 NaN              NaN
# 315                                 NaN              NaN
#
#     Country (Consignment) Destination  CIF/FOB Value (ETB)  FOB (FC)  \
# 311                 China    Ethiopia             470156.0   7800.00
# 312  United Arab Emirates    Ethiopia             118014.0   1968.75
# 313              Viet Nam    Ethiopia            3099373.0  47586.17
# 314                   NaN         NaN                  NaN       NaN
# 315                   NaN         NaN                  NaN       NaN
#
#     CURRENCY CODE  # of packages  MoT Code                  MoT Description  \
# 311           USD          999.0      61.0    UNIMODAL TRANSPORT (SEA ROAD)
# 312           USD          394.0      62.0  MULTIMODAL TRANSPORT (SEA ROAD)
# 313           USD         1609.0      61.0    UNIMODAL TRANSPORT (SEA ROAD)
# 314           NaN            NaN       NaN                              NaN
# 315           NaN            NaN       NaN                              NaN
#
#      Suppl. Quantity  Gross Wt. (Kg)  Net Wt. (Kg)  Duty tax tobe paid (ETB)  \
# 311              NaN         5200.00       5200.00                  23507.80
# 312              NaN          675.00        625.00                   5900.70
# 313              NaN        40466.35      40225.00                 154968.60
# 314              NaN      8537717.82           NaN                       NaN
# 315              NaN     17138519.95    8251825.38               41090428.92
#
#      Duty tax paid (ETB)  Excise tax tobe paid (ETB)  Excise tax paid (ETB)  \
# 311              23507.8                         0.0                    0.0
# 312               5900.7                         0.0                    0.0
# 313             154968.6                         0.0                    0.0
# 314                  NaN                         NaN                    NaN
# 315                  NaN                         NaN                    NaN
#
#      VAT tobe paid (ETB)  VAT paid (ETB)  WH tax tobe paid (ETB)  \
# 311             74049.60        74049.60                14104.68
# 312             18587.25        18587.25                 3540.42
# 313            488151.30       488151.30                92981.19
# 314                  NaN             NaN                     NaN
# 315                  NaN             NaN                     NaN
#
#      WH tax paid (ETB)  Sur tax tobe paid (ETB)  Sur tax paid (ETB)  \
# 311               0.00                      0.0                 0.0
# 312            3540.42                      0.0                 0.0
# 313               0.00                      0.0                 0.0
# 314                NaN                      NaN                 NaN
# 315                NaN                      NaN                 NaN
#
#      Social Wel Tax tobe paid (ETB)  Social Wel Tax paid (ETB)  \
# 311                            0.00                       0.00
# 312                         3540.42                    3540.42
# 313                        92981.19                   92981.19
# 314                             NaN                        NaN
# 315                             NaN                        NaN
#
#      Total tax tobe paid (ETB)  Total tax paid (ETB)
# 311                  111662.08              97557.40
# 312                   31568.79              31568.79
# 313                  829082.28             736101.09
# 314                        NaN                   NaN
# 315                        NaN                   NaN

# %%
Chm_Import_data.shape
# Out:
# (316, 36)
